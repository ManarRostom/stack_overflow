# %% [markdown]
# <span style="color:#b30000;font-size:25px;"><strong>The emphasis of this Notebook lies in analyzing the columns that will serve as features during the Modeling phase</strong></span>

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Import Libraries</span>

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from sklearn.preprocessing import MultiLabelBinarizer
import plotly.graph_objects as go

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Read Dataset </span>

# %%
original_data = pd.read_csv('Data/Features.csv')

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Show Sample of The Dataset </span>

# %%
original_data.sample(5)
# Out:
#                                              DevType  \
# 40146                              Developer, mobile
# 46753                          Developer, full-stack
# 54860  Developer, desktop or enterprise applications
# 81722                    Developer, game or graphics
# 58274                                            NaN
#
#                                   LanguageHaveWorkedWith  \
# 40146                                              Swift
# 46753                            HTML/CSS;JavaScript;SQL
# 54860                           C#;C++;PowerShell;Python
# 81722  Groovy;HTML/CSS;Java;JavaScript;Kotlin;TypeScript
# 58274                HTML/CSS;Java;JavaScript;TypeScript
#
#              DatabaseHaveWorkedWith                  PlatformHaveWorkedWith  \
# 40146                  MySQL;SQLite      Amazon Web Services (AWS);Firebase
# 46753                 Elasticsearch  Amazon Web Services (AWS);Google Cloud
# 54860                           NaN                                     NaN
# 81722  Dynamodb;PostgreSQL;Supabase        Amazon Web Services (AWS);Vercel
# 58274             Oracle;PostgreSQL               Amazon Web Services (AWS)
#
#               WebframeHaveWorkedWith  \
# 40146                            NaN
# 46753          Express;Node.js;React
# 54860                            NaN
# 81722  Express;Next.js;Node.js;React
# 58274          NestJS;Node.js;Vue.js
#
#                              MiscTechHaveWorkedWith  \
# 40146                                       SwiftUI
# 46753                         RabbitMQ;React Native
# 54860  .NET (5+) ;.NET Framework (1.0 - 4.8);MFC;Qt
# 81722                          Electron;Ktor;OpenGL
# 58274                                  Apache Kafka
#
#                                  ToolsTechHaveWorkedWith  \
# 40146                                                NaN
# 46753                        Docker;Homebrew;npm;Webpack
# 54860  Chocolatey;MSBuild;MSVC;NuGet;Pacman;Pip;Visua...
# 81722        Ant;Chocolatey;Gradle;npm;Vite;Webpack;Yarn
# 58274                                           npm;Vite
#
#                             NEWCollabToolsHaveWorkedWith
# 40146                                              Xcode
# 46753                                           WebStorm
# 54860  Eclipse;Nano;Notepad++;Qt Creator;Rad Studio (...
# 81722  Eclipse;IntelliJ IDEA;Nano;Visual Studio Code;...
# 58274                             IntelliJ IDEA;WebStorm

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Show Shape of Dataset </span>

# %%
original_data.shape
# Out:
# (89184, 8)

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Check Duplication </span>

# %%
original_data.duplicated().sum()
# Out:
# 1961

# %%
original_data.drop_duplicates(inplace=True)

# %%
original_data.reset_index(drop=True, inplace=True)

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Check Null Values</span>

# %%
original_data.isnull().sum()
# Out:
# DevType                         10812
# LanguageHaveWorkedWith            409
# DatabaseHaveWorkedWith          13850
# PlatformHaveWorkedWith          23620
# WebframeHaveWorkedWith          20329
# MiscTechHaveWorkedWith          30255
# ToolsTechHaveWorkedWith          9406
# NEWCollabToolsHaveWorkedWith     1639
# dtype: int64

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Read Info of The Dataset</span>

# %%
original_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87223 entries, 0 to 87222
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   DevType                       76411 non-null  object
#  1   LanguageHaveWorkedWith        86814 non-null  object
#  2   DatabaseHaveWorkedWith        73373 non-null  object
#  3   PlatformHaveWorkedWith        63603 non-null  object
#  4   WebframeHaveWorkedWith        66894 non-null  object
#  5   MiscTechHaveWorkedWith        56968 non-null  object
#  6   ToolsTechHaveWorkedWith       77817 non-null  object
#  7   NEWCollabToolsHaveWorkedWith  85584 non-null  object
# dtypes: object(8)
# memory usage: 5.3+ MB

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Drop Rows that has Null values in DevType(Target)</span>

# %%
target_drop_idx = original_data[original_data['DevType'].isnull() == 1].index

# %%
original_data.drop(target_drop_idx, axis=0, inplace=True)

# %%
original_data.reset_index(drop=True, inplace=True)

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Apply Split_Answer function</span>

# %%
## Create Split_Answers Funcion
def Split_Answers(answer):
    if isinstance(answer, str):
        return answer.split(';')
    else:
        ## if answer is null function returns empty list
        return []

# %%
## Apply Split_Answer Funcion to each column in the dataset
data = pd.DataFrame()
for col in original_data.drop('DevType', axis=1).columns:
    data[col] = original_data[col].apply(Split_Answers)
data['DevType'] = original_data['DevType']

# %%
data.sample(5)
# Out:
#                                   LanguageHaveWorkedWith  \
# 59488                                               [C#]
# 51019                                     [C#, F#, Rust]
# 46366  [Bash/Shell (all shells), HTML/CSS, Java, Java...
# 47792                      [HTML/CSS, Java, Python, SQL]
# 8221                         [HTML/CSS, JavaScript, PHP]
#
#                    DatabaseHaveWorkedWith  \
# 59488                             [MySQL]
# 51019  [Microsoft SQL Server, PostgreSQL]
# 46366               [MongoDB, PostgreSQL]
# 47792           [MariaDB, Oracle, SQLite]
# 8221                                   []
#
#                           PlatformHaveWorkedWith  \
# 59488  [Amazon Web Services (AWS), Google Cloud]
# 51019   [Digital Ocean, Microsoft Azure, Render]
# 46366                [Amazon Web Services (AWS)]
# 47792                                         []
# 8221                                          []
#
#                                   WebframeHaveWorkedWith  \
# 59488                                        [WordPress]
# 51019                    [Angular, ASP.NET CORE, Svelte]
# 46366  [Express, jQuery, Node.js, React, Spring Boot,...
# 47792                                            [Flask]
# 8221                                            [jQuery]
#
#       MiscTechHaveWorkedWith  \
# 59488                     []
# 51019           [.NET (5+) ]
# 46366     [Spring Framework]
# 47792                     []
# 8221               [Xamarin]
#
#                                  ToolsTechHaveWorkedWith  \
# 59488                 [Unity 3D, Visual Studio Solution]
# 51019                                     [Cargo, NuGet]
# 46366  [Composer, Docker, Maven (build tool), npm, We...
# 47792                  [Docker, Maven (build tool), Pip]
# 8221                                                  []
#
#                             NEWCollabToolsHaveWorkedWith  \
# 59488     [Notepad++, Visual Studio, Visual Studio Code]
# 51019  [CLion, Goland, Visual Studio, Visual Studio C...
# 46366  [IntelliJ IDEA, Notepad++, Vim, Visual Studio ...
# 47792                 [IntelliJ IDEA, Sublime Text, Vim]
# 8221                          [Atom, Visual Studio Code]
#
#                            DevType
# 59488  Developer, game or graphics
# 51019            DevOps specialist
# 46366        Developer, full-stack
# 47792        Developer, full-stack
# 8221         Developer, full-stack

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Apply MultiLabel Binarizer to each column</span>

# %%
encoded_dfs = {}
for col in data.drop('DevType', axis=1).columns:
    mlb = MultiLabelBinarizer()
    mlb_df = pd.DataFrame(mlb.fit_transform(data[col]), columns=mlb.classes_)
    encoded_dfs[col] = mlb_df

# %%
## Merge encoded_dfs in one dataframe
df = pd.concat(encoded_dfs, axis=1)
df['DevType'] = data['DevType']

# %%
df.sample(5)
# Out:
#       LanguageHaveWorkedWith                                                  \
#                          APL Ada Apex Assembly Bash/Shell (all shells)  C C#
# 72503                      0   0    0        0                       0  0  0
# 20141                      0   0    0        0                       0  0  0
# 14496                      0   0    0        0                       0  0  1
# 43081                      0   0    0        0                       0  0  1
# 33822                      0   0    0        0                       0  0  1
#
#                          ... NEWCollabToolsHaveWorkedWith                    \
#       C++ Clojure Cobol  ...                 Sublime Text TextMate VSCodium
# 72503   0       0     0  ...                            0        0        0
# 20141   0       0     0  ...                            0        0        0
# 14496   0       0     0  ...                            0        0        0
# 43081   0       0     0  ...                            1        0        0
# 33822   0       0     0  ...                            0        0        0
#
#                                                                  \
#       Vim Visual Studio Visual Studio Code WebStorm Xcode condo
# 72503   0             0                  1        0     0     0
# 20141   0             0                  0        0     0     0
# 14496   0             0                  1        0     0     0
# 43081   0             0                  0        0     1     0
# 33822   0             1                  1        0     0     0
#
#                                              DevType
#
# 72503                           Developer, front-end
# 20141                          Developer, full-stack
# 14496                          Developer, full-stack
# 43081                          Security professional
# 33822  Developer, desktop or enterprise applications
#
# [5 rows x 271 columns]

# %%
## Display DevType Frequency
df['DevType'].value_counts().reset_index()
# Out:
#                                           DevType  count
# 0                           Developer, full-stack  25689
# 1                             Developer, back-end  13705
# 2                            Developer, front-end   5018
# 3   Developer, desktop or enterprise applications   3848
# 4                         Other (please specify):   3025
# 5                               Developer, mobile   2520
# 6                             Engineering manager   2025
# 7                                         Student   1966
# 8     Developer, embedded applications or devices   1837
# 9   Data scientist or machine learning specialist   1585
# 10                              DevOps specialist   1387
# 11                    Research & Development role   1348
# 12                            Academic researcher   1335
# 13           Senior Executive (C-Suite, VP, etc.)   1330
# 14                                 Engineer, data   1243
# 15                  Cloud infrastructure engineer   1036
# 16                    Developer, game or graphics    861
# 17                       Data or business analyst    829
# 18                           System administrator    735
# 19                                Project manager    585
# 20                          Developer, QA or test    582
# 21                          Security professional    472
# 22                                Product manager    443
# 23                     Engineer, site reliability    427
# 24                                       Educator    413
# 25                                      Scientist    347
# 26                           Developer Experience    326
# 27                                     Blockchain    322
# 28                              Hardware Engineer    283
# 29                                       Designer    273
# 30                         Database administrator    255
# 31                             Developer Advocate    212
# 32                Marketing or sales professional    149

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Display tree map for all skills  <span>

# %%
skills_freq = df.drop('DevType', axis=1).sum().reset_index()
skills_freq.columns = ['Group', 'Skill', 'Freq']
#skills_freq

# %%
fig_tree = px.treemap(skills_freq, path=['Group', 'Skill'],
                      values='Freq',
                      color='Freq', 
                      color_continuous_scale='deep')
fig_tree.show()
# Out:
# <div>                            <div id="ba62bad6-c635-4bc8-b92e-9365a1837e67" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba62bad6-c635-4bc8-b92e-9365a1837e67")) {                    Plotly.newPlot(                        "ba62bad6-c635-4bc8-b92e-9365a1837e67",                        [{"branchvalues":"total","customdata":[[15340.0],[10601.0],[1403.0],[150.0],[4850.0],[8677.0],[11337.0],[551.0],[32159.0],[12258.0],[11845.0],[4901.0],[6645.0],[2204.0],[5827.0],[2584.0],[538.0],[3381.0],[3994.0],[676.0],[25001.0],[3300.0],[3287.0],[298.0],[489.0],[12855.0],[21420.0],[15301.0],[3230.0],[9293.0],[2502.0],[42.0],[1027.0],[8197.0],[1802.0],[587.0],[728.0],[5644.0],[804.0],[1012.0],[4147.0],[9296.0],[484.0],[703.0],[1341.0],[1178.0],[465.0],[5928.0],[1521.0],[2602.0],[822.0],[570.0],[332.0],[814.0],[4402.0],[4056.0],[219.0],[2560.0],[1369.0],[8634.0],[7082.0],[38537.0],[1271.0],[437.0],[6615.0],[35.0],[7338.0],[10026.0],[3867.0],[1869.0],[515.0],[3460.0],[797.0],[11924.0],[756.0],[4782.0],[1313.0],[9304.0],[4195.0],[1062.0],[7333.0],[1281.0],[193.0],[5182.0],[1458.0],[686.0],[1025.0],[7554.0],[1221.0],[1578.0],[646.0],[10501.0],[1801.0],[2574.0],[15064.0],[1953.0],[10412.0],[2863.0],[2653.0],[39878.0],[1427.0],[1305.0],[1070.0],[7154.0],[2794.0],[16478.0],[1577.0],[707.0],[1348.0],[3641.0],[1954.0],[20022.0],[1812.0],[565.0],[22418.0],[48951.0],[765.0],[9173.0],[1059.0],[2319.0],[6898.0],[635.0],[14823.0],[4693.0],[5085.0],[2408.0],[1082.0],[445.0],[4056.0],[2636.0],[626.0],[8053.0],[3021.0],[13880.0],[2215.0],[12139.0],[10908.0],[796.0],[392.0],[415.0],[2804.0],[17280.0],[18587.0],[17143.0],[27807.0],[6512.0],[1287.0],[8237.0],[3409.0],[2401.0],[5300.0],[10482.0],[256.0],[2403.0],[1352.0],[26675.0],[18980.0],[218.0],[11452.0],[11116.0],[2372.0],[460.0],[2162.0],[1873.0],[3510.0],[1627.0],[1004.0],[4328.0],[6983.0],[1495.0],[14487.0],[3908.0],[10904.0],[1972.0],[1386.0],[4908.0],[19482.0],[516.0],[2900.0],[32399.0],[10638.0],[573.0],[640.0],[858.0],[10350.0],[35876.0],[830.0],[3568.0],[1687.0],[734.0],[322.0],[3062.0],[1945.0],[6751.0],[1755.0],[127.0],[212.0],[26133.0],[5079.0],[14856.0],[823.0],[1023.0],[4334.0],[5081.0],[3756.0],[1050.0],[9057.0],[376.0],[319.0],[38774.0],[20735.0],[2267.0],[584.0],[5282.0],[1773.0],[774.0],[1014.0],[1156.0],[8053.0],[7038.0],[1014.0],[9636.0],[1753.0],[3795.0],[3577.0],[2259.0],[2199.0],[1122.0],[5153.0],[8909.0],[548.0],[133.0],[907.0],[4773.0],[30880.0],[4011.0],[291.0],[1882.0],[2799.0],[4376.0],[2658.0],[6223.0],[17042.0],[3156.0],[21354.0],[55521.0],[10478.0],[10186.0],[10712.0],[1179.0],[373.0],[5656.0],[15580.0],[8689.0],[2049.0],[7420.0],[16221.0],[554.0],[328.0],[127.0],[115.0],[316.0],[335.0],[14430.0],[43.0],[26.0],[35326.0],[4328.0],[44.0],[52.0],[17447.716479662704],[26001.72939418467],[7050.840756752762],[20901.30820798915],[14779.141287870301],[16542.012716825804],[12977.71146760823]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Freq_sum=%{value}<br>parent=%{parent}<br>id=%{id}<br>Freq=%{color}<extra></extra>","ids":["MiscTechHaveWorkedWith/.NET (5+) ","MiscTechHaveWorkedWith/.NET Framework (1.0 - 4.8)","MiscTechHaveWorkedWith/.NET MAUI","LanguageHaveWorkedWith/APL","ToolsTechHaveWorkedWith/APT","WebframeHaveWorkedWith/ASP.NET","WebframeHaveWorkedWith/ASP.NET CORE","LanguageHaveWorkedWith/Ada","PlatformHaveWorkedWith/Amazon Web Services (AWS)","NEWCollabToolsHaveWorkedWith/Android Studio","WebframeHaveWorkedWith/Angular","WebframeHaveWorkedWith/AngularJS","ToolsTechHaveWorkedWith/Ansible","ToolsTechHaveWorkedWith/Ant","MiscTechHaveWorkedWith/Apache Kafka","MiscTechHaveWorkedWith/Apache Spark","LanguageHaveWorkedWith/Apex","LanguageHaveWorkedWith/Assembly","NEWCollabToolsHaveWorkedWith/Atom","NEWCollabToolsHaveWor ...

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Create Jobs & Skills Heatmap<span>

# %%
sorted_jobs = df['DevType'].value_counts(ascending=True).index.tolist()

# %%
sorted_skills = df.drop('DevType', axis=1).sum().sort_values(ascending=False).droplevel(level=0).index.tolist()

# %%
# dict for percentage of each skill exist in each skill column for each job
skills_jobs = {}

# iterate for each job
for job in sorted_jobs:
    skills_job = {} # dict for percentage of each skill exist in each skill column for one job
    
    # iterate for each skill column 
    for skill in data.drop('DevType', axis=1).columns:
        skill_job = df[df['DevType'] == job][skill].mean() * 100 
        skills_job[skill] = skill_job
        
    # concat dict of each skill column percentage for one job
    skills_job = pd.concat(skills_job)
    skills_jobs[job] = skills_job
    
# concat dict of each skill percentage of each job
skills_jobs = pd.concat(skills_jobs, axis=1)

# %%
skills_jobs = skills_jobs.reset_index(level=0, drop=True)
skills_jobs = skills_jobs.loc[sorted_skills]
skills_jobs = skills_jobs.T

# %%
skills_jobs
# Out:
#                                                Visual Studio Code  JavaScript  \
# Marketing or sales professional                         57.718121   56.375839
# Developer Advocate                                      73.584906   63.679245
# Database administrator                                  51.764706   29.803922
# Designer                                                59.706960   63.003663
# Hardware Engineer                                       59.363958   25.795053
# Blockchain                                              68.322981   62.422360
# Developer Experience                                    73.312883   55.214724
# Scientist                                               52.161383   27.953890
# Educator                                                65.859564   58.111380
# Engineer, site reliability                              71.896956   49.882904
# Product manager                                         67.494357   66.591422
# Security professional                                   68.855932   57.415254
# Developer, QA or test                                   72.680412   53.780069
# Project manager                                         67.008547   61.709402
# System administrator                                    60.544218   52.653061
# Data or business analyst                                63.329312   40.892642
# Developer, game or graphics                             70.383275   43.786295
# Cloud infrastructure engineer                           73.938224   50.579151
# Engineer, data                                          69.509252   35.961384
# Senior Executive (C-Suite, VP, etc.)                    69.548872   72.406015
# Academic researcher                                     59.176030   34.681648
# Research & Development role                             65.727003   40.949555
# DevOps specialist                                       76.063446   52.631579
# Data scientist or machine learning specialist           73.186120   31.419558
# Developer, embedded applications or devices             69.188895   30.157866
# Student                                                 80.213632   68.260427
# Engineering manager                                     72.444444   66.123457
# Developer, mobile                                       62.777778   37.063492
# Other (please specify):                                 67.834711   55.900826
# Developer, desktop or enterprise applications           61.564449   41.995842
# Developer, front-end                                    85.093663   91.988840
# Developer, back-end                                     66.661802   50.251733
# Developer, full-stack                                   79.458134   85.565806
#
#                                                 HTML/CSS        SQL  \
# Marketing or sales professional                55.704698  40.939597
# Developer Advocate                             56.603774  46.698113
# Database administrator                         31.764706  82.745098
# Designer                                       64.468864  30.769231
# Hardware Engineer                              27.915194  22.261484
# Blockchain                                     38.509317  30.434783
# Developer Experience                           38.343558  36.503067
# Scientist                                      25.360231  28.242075
# Educator                                       56.416465  46.004843
# Engineer, site reliability                     40.046838  44.496487
# Product manager                                53.724605  54.853273
# Security professional                          44.915254  45.762712
# Developer, QA or test                          38.144330  39.003436
# Project manager                                55.555556  56.410256
# System administrator                           51.700680  53.061224
# Data or business analyst                       40.289505  72.858866
# Developer, game or graphics                    33.797909  19.512195
# Cloud infrastructure engineer                  34.652510  42.760618
# Engineer, data                                 28.559936  72.646822
# Senior Executive (C-Suite, VP, etc.)           58.571429  59.924812
# Academic researcher                            32.808989  24.194757
# Research & Development role                    33.308605  36.646884
# DevOps specialist                              39.005047  48.377794
# Data scientist or machine learning specialist  28.075710  55.520505
# Developer, embedded applications or devices    22.591181  19.488296
# Student                                        64.649034  43.692777
# Engineering manager                            46.765432  53.876543
# Developer, mobile                              25.634921  24.206349
# Other (please specify):                        47.239669  47.636364
# Developer, desktop or enterprise applications  35.135135  49.298337
# Developer, front-end                           79.752890  24.770825
# Developer, back-end                            34.170011  53.411164
# Developer, full-stack                          71.956869  62.489782
#
#                                                   Docker     Python  \
# Marketing or sales professional                28.187919  45.637584
# Developer Advocate                             52.830189  42.452830
# Database administrator                         25.882353  42.745098
# Designer                                       21.978022  31.135531
# Hardware Engineer                              26.855124  70.671378
# Blockchain                                     52.795031  41.925466
# Developer Experience                           55.521472  49.693252
# Scientist                                      29.682997  78.097983
# Educator                                       28.087167  63.438257
# Engineer, site reliability                     72.131148  71.896956
# Product manager                                41.083521  44.243792
# Security professional                          58.686441  77.966102
# Developer, QA or test                          47.079038  59.793814
# Project manager                                37.435897  47.008547
# System administrator                           41.496599  57.551020
# Data or business analyst                       22.195416  67.430639
# Developer, game or graphics                    21.602787  45.063879
# Cloud infrastructure engineer                  74.517375  70.173745
# Engineer, data                                 61.866452  85.760257
# Senior Executive (C-Suite, VP, etc.)           59.172932  48.796992
# Academic researcher                            36.479401  79.475655
# Research & Development role                    49.480712  69.955490
# DevOps specialist                              77.577505  71.593367
# Data scientist or machine learning specialist  51.545741  93.817035
# Developer, embedded applications or devices    42.678280  69.025585
# Student                                        33.825025  71.566633
# Engineering manager                            62.716049  47.209877
# Developer, mobile                              21.706349  25.714286
# Other (please specify):                        39.603306  54.016529
# Developer, desktop or enterprise applications  27.728690  37.655925
# Developer, front-end                           37.325628  21.383021
# Developer, back-end                            63.312660  44.399854
# Developer, full-stack                          55.354432  39.643427
#
#                                                      npm  PostgreSQL  \
# Marketing or sales professional                32.214765   30.872483
# Developer Advocate                             43.867925   44.339623
# Database administrator                         11.372549   30.588235
# Designer                                       31.501832   17.216117
# Hardware Engineer                              15.901060   13.074205
# Blockchain                                     50.621118   50.310559
# Developer Experience                           41.411043   36.503067
# Scientist                                      12.391931   20.172911
# Educator                                       31.476998   29.782082
# Engineer, site reliability                     38.875878   55.503513
# Product manager                                38.148984   32.279910
# Security professional                          39.194915   41.525424
# Developer, QA or test                          39.518900   32.302405
# Project manager                                36.923077   38.803419
# System administrator                           26.666667   38.231293
# Data or business analyst                       17.249698   32.448733
# Developer, game or graphics                    26.713124   15.679443
# Cloud infrastructure engineer                  41.312741   54.343629
# Engineer, data                                 24.215607   55.430410
# Senior Executive (C-Suite, VP, etc.)           50.601504   54.210526
# Academic researcher                            19.101124   23.820225
# Research & Development role                    26.409496   33.605341
# DevOps specialist                              44.628695   55.948089
# Data scientist or machine learning specialist  19.242902   41.892744
# Developer, embedded applications or devices    15.514426   19.052803
# Student                                        46.337742   30.417091
# Engineering manager                            50.370370   52.296296
# Developer, mobile                              26.865079   19.642857
# Other (please specify):                        34.214876   34.016529
# Developer, desktop or enterprise applications  21.569647   23.908524
# Developer, front-end                           71.462734   28.118772
# Developer, back-end                            37.344035   54.002189
# Developer, full-stack                          64.696952   48.658959
#
#                                                Amazon Web Services (AWS)  \
# Marketing or sales professional                                32.214765
# Developer Advocate                                             50.943396
# Database administrator                                         29.803922
# Designer                                                       21.978022
# Hardware Engineer                                              14.840989
# Blockchain                                                     50.931677
# Developer Experience                                           51.226994
# Scientist                                                      21.613833
# Educator                                                       25.181598
# Engineer, site reliability                                     64.402810
# Product manager                                                44.469526
# Security professional                                          52.754237
# Developer, QA or test                                          37.457045
# Project manager                                                35.213675
# System administrator                                           24.761905
# Data or business analyst                                       23.642943
# Developer, game or graphics                                    22.531940
# Cloud infrastructure engineer                                  71.621622
# Engineer, data                                                 56.958970
# Senior Executive (C-Suite, VP, etc.)                           61.127820
# Academic researcher                                            19.026217
# Research & Development role                                    33.902077
# DevOps specialist                                              59.192502
# Data scientist or machine learning specialist                  51.041009
# Developer, embedded applications or devices                    19.379423
# Student                                                        18.209563
# Engineering manager                                            60.691358
# Developer, mobile                                              27.500000
# Other (please specify):                                        34.082645
# Developer, desktop or enterprise applications                  21.517672
# Developer, front-end                                           33.838183
# Developer, back-end                                            51.995622
# Developer, full-stack                                          45.447468
#
#                                                TypeScript  ...      TiDB  \
# Marketing or sales professional                 16.778523  ...  2.684564
# Developer Advocate                              34.433962  ...  0.000000
# Database administrator                           6.666667  ...  0.784314
# Designer                                        18.681319  ...  0.000000
# Hardware Engineer                                7.067138  ...  0.000000
# Blockchain                                      52.484472  ...  0.621118
# Developer Experience                            40.184049  ...  0.613497
# Scientist                                        7.204611  ...  0.288184
# Educator                                        20.096852  ...  0.000000
# Engineer, site reliability                      31.850117  ...  0.234192
# Product manager                                 27.765237  ...  1.128668
# Security professional                           24.576271  ...  0.423729
# Developer, QA or test                           27.147766  ...  0.171821
# Project manager                                 26.495726  ...  0.000000
# System administrator                            14.965986  ...  0.136054
# Data or business analyst                        13.268999  ...  0.241255
# Developer, game or graphics                     24.506388  ...  0.000000
# Cloud infrastructure engineer                   33.108108  ...  0.868726
# Engineer, data                                  15.124698  ...  0.482703
# Senior Executive (C-Suite, VP, etc.)            45.112782  ...  0.601504
# Academic researcher                             13.707865  ...  0.224719
# Research & Development role                     21.364985  ...  0.074184
# DevOps specialist                               31.146359  ...  0.504686
# Data scientist or machine learning specialist   12.555205  ...  0.063091
# Developer, embedded applications or devices     12.574850  ...  0.000000
# Student                                         34.689725  ...  0.254323
# Engineering manager                             44.839506  ...  0.098765
# Developer, mobile                               19.682540  ...  0.198413
# Other (please specify):                         26.776860  ...  0.264463
# Developer, desktop or enterprise applications   18.399168  ...  0.129938
# Developer, front-end                            70.745317  ...  0.039857
# Developer, back-end                             30.266326  ...  0.204305
# Developer, full-stack                           59.951730  ...  0.077854
#
#                                                  build2      Raku     condo  \
# Marketing or sales professional                2.013423  0.671141  1.342282
# Developer Advocate                             0.000000  0.000000  0.000000
# Database administrator                         0.392157  0.392157  0.392157
# Designer                                       0.366300  0.732601  0.366300
# Hardware Engineer                              0.000000  1.060071  0.353357
# Blockchain                                     0.931677  0.310559  0.621118
# Developer Experience                           0.920245  0.000000  1.226994
# Scientist                                      0.288184  0.288184  0.576369
# Educator                                       0.000000  0.242131  0.242131
# Engineer, site reliability                     0.000000  0.234192  0.234192
# Product manager                                0.000000  0.000000  0.677201
# Security professional                          0.423729  0.211864  0.211864
# Developer, QA or test                          0.000000  0.171821  0.343643
# Project manager                                0.000000  0.170940  0.000000
# System administrator                           0.136054  1.224490  0.136054
# Data or business analyst                       0.361882  0.120627  0.482509
# Developer, game or graphics                    0.813008  0.000000  0.116144
# Cloud infrastructure engineer                  0.386100  0.289575  0.193050
# Engineer, data                                 0.160901  0.241352  0.321802
# Senior Executive (C-Suite, VP, etc.)           0.075188  0.526316  0.300752
# Academic researcher                            0.524345  0.449438  0.524345
# Research & Development role                    0.370920  0.370920  0.445104
# DevOps specialist                              0.288392  0.216294  0.144196
# Data scientist or machine learning specialist  0.126183  0.126183  0.694006
# Developer, embedded applications or devices    0.489929  0.108873  0.000000
# Student                                        0.356053  0.559512  0.457782
# Engineering manager                            0.148148  0.049383  0.098765
# Developer, mobile                              0.119048  0.158730  0.119048
# Other (please specify):                        0.264463  0.297521  0.165289
# Developer, desktop or enterprise applications  0.233888  0.129938  0.129938
# Developer, front-end                           0.059785  0.059785  0.019928
# Developer, back-end                            0.072966  0.138636  0.058373
# Developer, full-stack                          0.097318  0.077854  0.073962
#
#                                                   tunit    snitch      lest  \
# Marketing or sales professional                1.342282  0.671141  0.671141
# Developer Advocate                             0.471698  0.000000  0.471698
# Database administrator                         0.392157  0.392157  0.000000
# Designer                                       0.000000  0.000000  0.000000
# Hardware Engineer                              0.353357  0.000000  0.000000
# Blockchain                                     0.621118  0.310559  0.621118
# Developer Experience                           0.306748  0.306748  0.306748
# Scientist                                      0.288184  0.288184  0.288184
# Educator                                       0.000000  0.000000  0.000000
# Engineer, site reliability                     0.000000  0.000000  0.234192
# Product manager                                0.000000  0.000000  0.225734
# Security professional                          0.000000  0.211864  0.211864
# Developer, QA or test                          0.000000  0.000000  0.000000
# Project manager                                0.000000  0.000000  0.000000
# System administrator                           0.136054  0.000000  0.272109
# Data or business analyst                       0.241255  0.241255  0.361882
# Developer, game or graphics                    0.116144  0.116144  0.000000
# Cloud infrastructure engineer                  0.193050  0.386100  0.193050
# Engineer, data                                 0.000000  0.160901  0.080451
# Senior Executive (C-Suite, VP, etc.)           0.225564  0.225564  0.075188
# Academic researcher                            0.299625  0.224719  0.224719
# Research & Development role                    0.000000  0.000000  0.000000
# DevOps specialist                              0.072098  0.000000  0.072098
# Data scientist or machine learning specialist  0.000000  0.000000  0.000000
# Developer, embedded applications or devices    0.000000  0.054437  0.108873
# Student                                        0.152594  0.152594  0.203459
# Engineering manager                            0.049383  0.000000  0.049383
# Developer, mobile                              0.158730  0.119048  0.119048
# Other (please specify):                        0.033058  0.033058  0.066116
# Developer, desktop or enterprise applications  0.155925  0.129938  0.025988
# Developer, front-end                           0.019928  0.039857  0.059785
# Developer, back-end                            0.021890  0.021890  0.029186
# Developer, full-stack                          0.038927  0.019464  0.003893
#
#                                                    CUTE    ELFspy  \
# Marketing or sales professional                1.342282  0.671141
# Developer Advocate                             0.000000  0.000000
# Database administrator                         0.000000  0.000000
# Designer                                       0.000000  0.000000
# Hardware Engineer                              0.353357  0.000000
# Blockchain                                     0.310559  0.310559
# Developer Experience                           0.613497  0.306748
# Scientist                                      0.000000  0.000000
# Educator                                       0.000000  0.000000
# Engineer, site reliability                     0.000000  0.000000
# Product manager                                0.000000  0.000000
# Security professional                          0.423729  0.211864
# Developer, QA or test                          0.000000  0.000000
# Project manager                                0.000000  0.000000
# System administrator                           0.000000  0.000000
# Data or business analyst                       0.241255  0.241255
# Developer, game or graphics                    0.000000  0.000000
# Cloud infrastructure engineer                  0.193050  0.193050
# Engineer, data                                 0.080451  0.000000
# Senior Executive (C-Suite, VP, etc.)           0.075188  0.075188
# Academic researcher                            0.224719  0.149813
# Research & Development role                    0.000000  0.000000
# DevOps specialist                              0.072098  0.144196
# Data scientist or machine learning specialist  0.000000  0.000000
# Developer, embedded applications or devices    0.000000  0.000000
# Student                                        0.254323  0.305188
# Engineering manager                            0.000000  0.000000
# Developer, mobile                              0.238095  0.119048
# Other (please specify):                        0.033058  0.066116
# Developer, desktop or enterprise applications  0.077963  0.077963
# Developer, front-end                           0.039857  0.000000
# Developer, back-end                            0.014593  0.014593
# Developer, full-stack                          0.019464  0.023356
#
#                                                liblittletest
# Marketing or sales professional                     0.671141
# Developer Advocate                                  0.000000
# Database administrator                              0.000000
# Designer                                            0.000000
# Hardware Engineer                                   0.353357
# Blockchain                                          0.310559
# Developer Experience                                0.000000
# Scientist                                           0.288184
# Educator                                            0.000000
# Engineer, site reliability                          0.000000
# Product manager                                     0.000000
# Security professional                               0.211864
# Developer, QA or test                               0.000000
# Project manager                                     0.000000
# System administrator                                0.000000
# Data or business analyst                            0.241255
# Developer, game or graphics                         0.000000
# Cloud infrastructure engineer                       0.096525
# Engineer, data                                      0.000000
# Senior Executive (C-Suite, VP, etc.)                0.075188
# Academic researcher                                 0.299625
# Research & Development role                         0.000000
# DevOps specialist                                   0.000000
# Data scientist or machine learning specialist       0.000000
# Developer, embedded applications or devices         0.000000
# Student                                             0.203459
# Engineering manager                                 0.000000
# Developer, mobile                                   0.119048
# Other (please specify):                             0.099174
# Developer, desktop or enterprise applications       0.051975
# Developer, front-end                                0.000000
# Developer, back-end                                 0.000000
# Developer, full-stack                               0.003893
#
# [33 rows x 270 columns]

# %%
fig = go.Figure(data=go.Heatmap(z=skills_jobs, x = skills_jobs.columns , y = skills_jobs.index))
fig.update_layout(width=5000, height=800)
fig.show()
fig.write_html('Skills_Jobs.html')
# Out:
# <div>                            <div id="2bd6635d-2da4-4482-af89-3f98882302e7" class="plotly-graph-div" style="height:800px; width:5000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2bd6635d-2da4-4482-af89-3f98882302e7")) {                    Plotly.newPlot(                        "2bd6635d-2da4-4482-af89-3f98882302e7",                        [{"x":["Visual Studio Code","JavaScript","HTML/CSS","SQL","Docker","Python","npm","PostgreSQL","Amazon Web Services (AWS)","TypeScript","MySQL","Node.js","React","Bash/Shell (all shells)","Java","C#","Visual Studio","SQLite","IntelliJ IDEA","Pip","Notepad++","Microsoft SQL Server","Microsoft Azure","MongoDB","Vim","Homebrew","Yarn","Webpack",".NET (5+) ","C++","Google Cloud","Redis","Kubernetes","PHP","jQuery","Make","C","Android Studio","MariaDB","Express","Angular","NuGet","ASP.NET CORE","NumPy","Maven (build tool)","Pandas","Vue.js","PowerShell",".NET Framework (1.0 - 4.8)","Go","Next.js","Visual Studio Solution","Gradle","PyCharm","Vite","Elasticsearch","Sublime Text","Firebase","Cloudflare","CMake","Jupyter Notebook/JupyterLab","Rust","Terraform","WordPress","ASP.NET","Digital Ocean","Neovim","Cargo","Spring Boot","MSBuild","GNU GCC","Xcode","Eclipse","Flask","Heroku","Django","Spring Framework","Oracle","Kotlin","RabbitMQ","Ansible","Dynamodb","Nano","Vercel","Composer","Apache Kafka","WebStorm","Chocolatey","Netlify","Scikit-Learn","Flutter","TensorFlow","Laravel","Ruby","React Native","PhpStorm","AngularJS","APT","FastAPI","Torch/PyTorch","LLVM's Clang","Dart","VMware","Rider","pnpm","Opencv","Firebase Realtime Database","Cloud Firestore","Lua","DataGrip","Unity 3D","Atom","Pacman","Electron","Svelte","Ruby on Rails","IPython","Swift","Qt","OpenGL","Emacs","NestJS","Assembly","BigQuery","Blazor","CLion","Visual Basic (.Net)","R","MSVC","Podman","Groovy","Microsoft Access","VBA","Hetzner","VSCodium","H2","MATLAB","Cosmos DB","Apache Spark","Goland","Delphi","CUDA","Linode, now Akamai","Ninja","Netbeans","Nuxt.js","Keras","Scala","SwiftUI","Managed Hosting","Ant","Symfony","OVH","Xamarin","Perl","InfluxDB","Google Test","RStudio","Unreal Engine","Objective-C","Elixir","Ionic","Cassandra","Godot","Snowflake","Rad Studio (Delphi, C++ Builder)","Supabase","Qt Creator","OpenShift","Gatsby","Hugging Face Transformers","Cordova","Oracle Cloud Infrastructure (OCI)","Fly.io","Hadoop",".NET MAUI","Phoenix","Deno","Nix","IBM DB2","Code::Blocks","Fastify","Haskell","Neo4J","Fleet","Drupal","GTK","Vultr","CodeIgniter","Solr","Tauri","Lisp","Helix","Firebird","Kate","RubyMine","Capacitor","GDScript","Render","Solidity","Spyder","Clojure","OpenStack","Tidyverse","Puppet","QMake","Remix","Couch DB","Dagger","Clickhouse","Erlang","Meson","Solid.js","Julia","F#","Quarkus","Chef","IBM Cloud Or Watson","Cockroachdb","Fortran","BBEdit","Geany","Pulumi","Ktor","MFC","Catch2","Scaleway","Prolog","Couchbase","JAX","Zig","Ada","TextMate","Apex","Play Framework","Elm","Bun","Cobol","Colocation","OCaml","Lit","DuckDB","Micronaut","Micro","SAS","Wasmer","doctest","Crystal","bandit","Qwik","SCons","cppunit","Boost.Test","Uno Platform","Nim","Datomic","Nova","RavenDB","Flow","APL","TiDB","build2","Raku","condo","tunit","snitch","lest","CUTE","ELFspy","liblittletest"],"y":["Marketing or sales professional","Developer Advocate","Database administrator","Designer","Hardware Engineer","Blockchain","Developer Experience","Scientist","Educator","Engineer, site reliability","Product manager","Security professional","Developer, QA or test","Project manager","System administrator","Data or business analyst","Developer, game or graphics","Cloud infrastructure engineer","Engineer, data","Senior Executive (C-Suite, VP, etc.)","Academic researcher","Research & Development role","DevOps specialist","Data scientist or machine learning special ...

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Create Scaled Jobs & Skills Heatmap<span>

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_skills_jobs = pd.DataFrame(scaler.fit_transform(skills_jobs), columns=skills_jobs.columns, index=skills_jobs.index)

# %%
fig = go.Figure(data=go.Heatmap(z=scaled_skills_jobs, x = scaled_skills_jobs.columns , y = scaled_skills_jobs.index))
fig.update_layout(width=5000, height=800)
fig.show()
fig.write_html('Scaled_Skills_Jobs.html')
# Out:
# <div>                            <div id="5b94b3f9-0b6f-489b-b3d9-e1e179f47c82" class="plotly-graph-div" style="height:800px; width:5000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b94b3f9-0b6f-489b-b3d9-e1e179f47c82")) {                    Plotly.newPlot(                        "5b94b3f9-0b6f-489b-b3d9-e1e179f47c82",                        [{"x":["Visual Studio Code","JavaScript","HTML/CSS","SQL","Docker","Python","npm","PostgreSQL","Amazon Web Services (AWS)","TypeScript","MySQL","Node.js","React","Bash/Shell (all shells)","Java","C#","Visual Studio","SQLite","IntelliJ IDEA","Pip","Notepad++","Microsoft SQL Server","Microsoft Azure","MongoDB","Vim","Homebrew","Yarn","Webpack",".NET (5+) ","C++","Google Cloud","Redis","Kubernetes","PHP","jQuery","Make","C","Android Studio","MariaDB","Express","Angular","NuGet","ASP.NET CORE","NumPy","Maven (build tool)","Pandas","Vue.js","PowerShell",".NET Framework (1.0 - 4.8)","Go","Next.js","Visual Studio Solution","Gradle","PyCharm","Vite","Elasticsearch","Sublime Text","Firebase","Cloudflare","CMake","Jupyter Notebook/JupyterLab","Rust","Terraform","WordPress","ASP.NET","Digital Ocean","Neovim","Cargo","Spring Boot","MSBuild","GNU GCC","Xcode","Eclipse","Flask","Heroku","Django","Spring Framework","Oracle","Kotlin","RabbitMQ","Ansible","Dynamodb","Nano","Vercel","Composer","Apache Kafka","WebStorm","Chocolatey","Netlify","Scikit-Learn","Flutter","TensorFlow","Laravel","Ruby","React Native","PhpStorm","AngularJS","APT","FastAPI","Torch/PyTorch","LLVM's Clang","Dart","VMware","Rider","pnpm","Opencv","Firebase Realtime Database","Cloud Firestore","Lua","DataGrip","Unity 3D","Atom","Pacman","Electron","Svelte","Ruby on Rails","IPython","Swift","Qt","OpenGL","Emacs","NestJS","Assembly","BigQuery","Blazor","CLion","Visual Basic (.Net)","R","MSVC","Podman","Groovy","Microsoft Access","VBA","Hetzner","VSCodium","H2","MATLAB","Cosmos DB","Apache Spark","Goland","Delphi","CUDA","Linode, now Akamai","Ninja","Netbeans","Nuxt.js","Keras","Scala","SwiftUI","Managed Hosting","Ant","Symfony","OVH","Xamarin","Perl","InfluxDB","Google Test","RStudio","Unreal Engine","Objective-C","Elixir","Ionic","Cassandra","Godot","Snowflake","Rad Studio (Delphi, C++ Builder)","Supabase","Qt Creator","OpenShift","Gatsby","Hugging Face Transformers","Cordova","Oracle Cloud Infrastructure (OCI)","Fly.io","Hadoop",".NET MAUI","Phoenix","Deno","Nix","IBM DB2","Code::Blocks","Fastify","Haskell","Neo4J","Fleet","Drupal","GTK","Vultr","CodeIgniter","Solr","Tauri","Lisp","Helix","Firebird","Kate","RubyMine","Capacitor","GDScript","Render","Solidity","Spyder","Clojure","OpenStack","Tidyverse","Puppet","QMake","Remix","Couch DB","Dagger","Clickhouse","Erlang","Meson","Solid.js","Julia","F#","Quarkus","Chef","IBM Cloud Or Watson","Cockroachdb","Fortran","BBEdit","Geany","Pulumi","Ktor","MFC","Catch2","Scaleway","Prolog","Couchbase","JAX","Zig","Ada","TextMate","Apex","Play Framework","Elm","Bun","Cobol","Colocation","OCaml","Lit","DuckDB","Micronaut","Micro","SAS","Wasmer","doctest","Crystal","bandit","Qwik","SCons","cppunit","Boost.Test","Uno Platform","Nim","Datomic","Nova","RavenDB","Flow","APL","TiDB","build2","Raku","condo","tunit","snitch","lest","CUTE","ELFspy","liblittletest"],"y":["Marketing or sales professional","Developer Advocate","Database administrator","Designer","Hardware Engineer","Blockchain","Developer Experience","Scientist","Educator","Engineer, site reliability","Product manager","Security professional","Developer, QA or test","Project manager","System administrator","Data or business analyst","Developer, game or graphics","Cloud infrastructure engineer","Engineer, data","Senior Executive (C-Suite, VP, etc.)","Academic researcher","Research & Development role","DevOps specialist","Data scientist or machine learning special ...

# %% [markdown]
# ## From the previous visualizations we noticed that scaling the data makes the value of each skill more expressive to each job
#
#
# - For example before scaling the percentage of Keras in Data Science is 34.3 out of 100 but after scaling the value becomes 5.02 out of 6 which is more expressive
#
# - Another example , before scaling Unity 3D in Game/Graphics Developing is 44.7 out of 100 but after scaling the value becomes 5.4 out of 6 which is also more expressive
#
# - Another example , before scaling Visual Studio Code in Database Administration is 51.7 out of 100 but after scaling the value becomes -2.1 out of 6 which is also more expressive .. etc

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Jop Profiles<span>

# %%
#job = np.random.choice(sorted_jobs)
job = 'Data scientist or machine learning specialist'
#job = 'Marketing or sales professional'
#job = 'Developer, back-end'
#job = 'Developer, front-end'
#job = 'Developer, full-stack'
#job = 'Data or business analyst'
#job = 'Database administrator'

# %%
job
# Out:
# 'Data scientist or machine learning specialist'

# %%
single_job_skills = pd.concat([skills_jobs.loc[job], scaled_skills_jobs.loc[job]], axis=1)
single_job_skills.columns = ['Percentage', 'Scaled_Value']
single_job_skills = single_job_skills.sort_values('Percentage')

# %%
single_job_skills.head()
# Out:
#                Percentage  Scaled_Value
# liblittletest         0.0     -0.606721
# CUTE                  0.0     -0.537147
# lest                  0.0     -0.855274
# snitch                0.0     -0.788875
# tunit                 0.0     -0.662249

# %%
## Comparing skills before and after scaling for random job
threshold = 25

single_job_skills = single_job_skills[single_job_skills['Percentage'] > threshold]

fig = px.bar(x=single_job_skills['Percentage'],
             y=single_job_skills.index,
             color=single_job_skills['Scaled_Value'],
             color_continuous_scale='orrd',
            range_color=[scaled_skills_jobs.min().min(), scaled_skills_jobs.max().max()])
fig.update_layout(title=job)
fig.show()
# Out:
# <div>                            <div id="500180d6-8c67-4239-9f85-f065a7fec5f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("500180d6-8c67-4239-9f85-f065a7fec5f0")) {                    Plotly.newPlot(                        "500180d6-8c67-4239-9f85-f065a7fec5f0",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0.4610282438437652,2.930443544730487,-1.0865486208562054,2.7630720588706197,0.2234134932360841,4.171085612651231,1.4090928703964116,-1.2992683660161373,3.693578549658019,2.6246338377467606,-0.05808869628082738,5.024815836302393,-0.0762716195832753,0.45185294173828605,4.693949077369929,0.7901014927995093,4.674241852732436,0.4530431394332847,0.7028279949735745,2.474763940421945,3.69087123018261,4.520574623713444,0.728006170024914,3.399632763858116,3.535166564404448,2.1186843431629354],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[25.299684542586753,27.57097791798107,28.075709779179807,28.580441640378552,28.83280757097792,29.14826498422713,31.230283911671926,31.41955835962145,31.861198738170348,32.17665615141956,32.49211356466877,34.321766561514195,35.709779179810724,41.89274447949527,46.05678233438486,51.041009463722396,51.16719242902208,51.54574132492114,55.520504731861195,56.845425867507885,63.154574132492115,67.63406940063092,73.18611987381703,75.45741324921136,76.27760252365931,93.81703470031546],"xaxis":"x","y":["Microsoft Azure","Flask","HTML/CSS","R","SQLite","Opencv","Google Cloud","JavaScript","IPython","PyCharm","MySQL","Keras","Bash/Shell (all shells)","PostgreSQL","TensorFlow","Amazon Web Services (AWS)","Torch/PyTorch","Docker","SQL","Pip","Jupyter Notebook/JupyterLab","Scikit-Learn","Visual Studio Code","NumPy","Pandas","Python"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222 ...

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Display Dendogram for this Data<span>

# %%
## Dict for replace long columns names
dict_Devtype = {'Senior Executive (C-Suite, VP, etc.)':'Senior Executive',
                'Developer, back-end':'Back-End',
                'Developer, front-end':'Front-End',
                'Developer, full-stack':'Full-Stack',
                'Developer, desktop or enterprise applications':'Desktop Developer',
                'Developer, QA or test':'Tester',
                'Data scientist or machine learning specialist':'Data Scientist',
                'Data or business analyst':'Data Analyst',
                'Developer, embedded applications or devices':'Embedded Developer',
                'Marketing or sales professional':'Marketing/Sales',  
}

short_labels = scaled_skills_jobs.index.to_series().replace(dict_Devtype).tolist()

import scipy.cluster.hierarchy as sch
import plotly.figure_factory as ff

fig_dendo = ff.create_dendrogram(scaled_skills_jobs, labels=short_labels, orientation='left')
fig_dendo.update_layout(width=1000, height=600)
fig_dendo.show()
# Out:
# <div>                            <div id="b4e81949-77a5-42c9-af8d-1b34dcd10b3b" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4e81949-77a5-42c9-af8d-1b34dcd10b3b")) {                    Plotly.newPlot(                        "b4e81949-77a5-42c9-af8d-1b34dcd10b3b",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,17.6749226958978,17.6749226958978,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,10.290251244984178,10.290251244984178,0.0],"xaxis":"x","y":[-35.0,-35.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,13.47311422539273,13.47311422539273,10.290251244984178],"xaxis":"x","y":[-25.0,-25.0,-40.0,-40.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,15.60580458421688,15.60580458421688,0.0],"xaxis":"x","y":[-55.0,-55.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,10.314965598352751,10.314965598352751,0.0],"xaxis":"x","y":[-95.0,-95.0,-105.0,-105.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,13.682950531105954,13.682950531105954,10.314965598352751],"xaxis":"x","y":[-85.0,-85.0,-100.0,-100.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,14.56677373569823,14.56677373569823,13.682950531105954],"xaxis":"x","y":[-75.0,-75.0,-92.5,-92.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,10.559640336934587,10.559640336934587,0.0],"xaxis":"x","y":[-115.0,-115.0,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,12.824847680698445,12.824847680698445,0.0],"xaxis":"x","y":[-135.0,-135.0,-145.0,-145.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[10.559640336934587,17.04814581944366,17.04814581944366,12.824847680698445],"xaxis":"x","y":[-120.0,-120.0,-140.0,-140.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[14.56677373569823,18.85300058872219,18.85300058872219,17.04814581944366],"xaxis":"x","y":[-83.75,-83.75,-130.0,-130.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[15.60580458421688,20.925738404758842,20.925738404758842,18.85300058872219],"xaxis":"x","y":[-60.0,-60.0,-106.875,-106.875],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[13.47311422539273,24.89890398522649,24.89890398522649,20.925738404758842],"xaxis":"x","y":[-32.5,-32.5,-83.4375,-83.4375],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[17.6749226958978,29.010800445290528,29.010800445290528,24.89890398522649],"xaxis":"x","y":[-10.0,-10.0,-57.96875,-57.96875],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.0,17.410418124409837,17.410418124409837,0.0],"xaxis":"x","y":[-175.0,-175.0,-185.0,-185.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.0,20.19634092355714,20.19634092355714,17.410418124409837],"xaxis":"x","y":[-165.0,-165.0,-180.0,-180.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.0,22.192975373309412,22.19297 ...

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Drop rows that has illogical Number of skills from original dataframe (Data) <span>

# %%
data.head()
# Out:
#                               LanguageHaveWorkedWith  \
# 0                     [HTML/CSS, JavaScript, Python]
# 1                      [Bash/Shell (all shells), Go]
# 2  [Bash/Shell (all shells), HTML/CSS, JavaScript...
# 3                 [HTML/CSS, JavaScript, TypeScript]
# 4  [Bash/Shell (all shells), HTML/CSS, JavaScript...
#
#                            DatabaseHaveWorkedWith  \
# 0                                      [Supabase]
# 1                                              []
# 2                             [PostgreSQL, Redis]
# 3  [BigQuery, Elasticsearch, MongoDB, PostgreSQL]
# 4  [BigQuery, Cloud Firestore, PostgreSQL, Redis]
#
#                               PlatformHaveWorkedWith  \
# 0       [Amazon Web Services (AWS), Netlify, Vercel]
# 1  [Amazon Web Services (AWS), Google Cloud, Open...
# 2                               [Cloudflare, Heroku]
# 3  [Amazon Web Services (AWS), Firebase, Heroku, ...
# 4  [Amazon Web Services (AWS), Cloudflare, Google...
#
#                               WebframeHaveWorkedWith  \
# 0                    [Next.js, React, Remix, Vue.js]
# 1                                                 []
# 2  [Node.js, React, Ruby on Rails, Vue.js, WordPr...
# 3  [Express, Gatsby, NestJS, Next.js, Node.js, Re...
# 4                [Angular, Express, NestJS, Node.js]
#
#             MiscTechHaveWorkedWith  \
# 0  [Electron, React Native, Tauri]
# 1                               []
# 2                               []
# 3                               []
# 4                               []
#
#                              ToolsTechHaveWorkedWith  \
# 0  [Docker, Kubernetes, npm, Pip, Vite, Webpack, ...
# 1             [Cargo, Docker, Kubernetes, Make, Nix]
# 2               [Homebrew, npm, Vite, Webpack, Yarn]
# 3                       [Docker, npm, Webpack, Yarn]
# 4  [Docker, Homebrew, Kubernetes, npm, pnpm, Terr...
#
#                         NEWCollabToolsHaveWorkedWith  \
# 0                          [Vim, Visual Studio Code]
# 1                                     [Emacs, Helix]
# 2  [IntelliJ IDEA, Vim, Visual Studio Code, WebSt...
# 3                          [Vim, Visual Studio Code]
# 4                                    [Helix, Neovim]
#
#                                 DevType
# 0  Senior Executive (C-Suite, VP, etc.)
# 1                   Developer, back-end
# 2                  Developer, front-end
# 3                 Developer, full-stack
# 4                   Developer, back-end

# %%
def Count_Total_Skills(row):
    return sum(len(List) for List in row)

# %%
Total_Skills_Count = data[data.columns[1:]].apply(Count_Total_Skills, axis=1)

# %%
px.histogram(Total_Skills_Count, title='Total Skills Count')
# Out:
# <div>                            <div id="896338ff-9300-4a77-90b9-11b1c745deef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("896338ff-9300-4a77-90b9-11b1c745deef")) {                    Plotly.newPlot(                        "896338ff-9300-4a77-90b9-11b1c745deef",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=0<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"x":[56,31,38,42,38,55,54,44,42,58,41,61,31,29,56,32,34,14,39,30,57,32,33,24,27,42,86,26,39,29,38,47,31,30,17,36,45,37,28,41,33,26,42,22,32,34,30,35,24,19,31,27,56,17,28,32,52,32,36,29,36,39,48,32,26,17,29,34,22,36,28,28,43,36,37,33,39,29,47,36,39,37,66,59,29,57,57,34,50,45,51,37,31,32,31,34,29,32,39,38,34,56,47,62,38,43,32,48,49,22,31,54,51,49,26,61,37,29,57,18,61,31,37,35,62,44,33,39,36,38,68,53,45,39,29,38,51,38,56,28,40,54,34,26,25,42,74,31,36,23,44,50,14,28,35,48,38,19,41,32,34,41,20,65,56,27,24,76,41,36,39,41,25,58,36,29,43,55,31,34,56,38,28,35,65,60,61,41,47,59,48,42,31,31,37,27,24,81,43,27,34,43,49,62,29,47,50,39,32,29,49,32,36,25,25,33,28,28,47,21,23,41,44,32,33,27,40,33,58,48,28,26,30,56,44,46,55,36,40,46,33,28,47,37,26,53,52,24,30,25,33,58,34,41,22,67,28,40,37,52,40,58,35,19,32,27,37,41,33,32,30,40,57,36,43,95,30,39,31,47,27,44,39,56,38,52,20,32,27,23,35,25,29,30,64,23,30,34,25,26,40,59,30,34,49,33,60,31,26,23,31,35,26,59,40,36,25,27,47,36,60,51,69,32,63,25,24,39,34,36,35,32,55,24,42,33,34,27,31,43,40,17,42,40,41,29,65,32,40,59,60,25,53,38,30,31,35,22,30,31,56,24,32,46,47,92,37,27,37,29,80,49,18,48,36,39,69,47,46,25,29,45,32,31,49,43,23,21,23,24,42,35,48,31,48,67,37,32,81,20,28,48,38,32,34,31,29,32,79,27,49,38,39,46,34,43,30,48,35,46,44,36,29,55,31,67,38,53,59,14,36,29,48,44,37,19,48,27,19,57,27,22,35,42,38,28,24,35,43,33,64,40,30,38,51,76,34,54,31,65,26,24,42,24,38,26,46,34,35,60,39,29,30,50,27,27,49,48,46,42,57,26,35,27,47,35,31,76,35,37,47,31,41,46,35,57,57,52,57,49,29,47,36,39,37,37,33,52,25,39,33,79,51,22,32,27,58,33,30,38,74,95,33,31,28,58,48,29,39,32,31,31,44,35,30,60,73,54,33,36,55,10,37,45,30,28,27,34,31,47,33,36,32,28,29,49,27,30,42,27,33,38,44,38,56,32,35,26,38,59,73,35,39,35,53,22,43,31,30,29,53,64,29,39,36,34,40,64,24,34,32,42,38,42,60,21,31,26,22,47,42,56,30,63,27,52,39,39,43,34,30,40,20,23,34,63,34,34,17,41,33,50,29,36,36,49,30,36,39,35,31,41,38,27,37,52,49,54,30,55,56,52,24,29,41,34,59,36,30,40,28,48,43,31,20,34,42,31,28,32,26,27,61,28,37,47,25,44,32,37,36,28,31,53,33,35,58,32,36,37,29,30,19,53,18,66,31,22,21,57,67,24,37,38,22,31,34,39,32,46,42,46,31,24,39,28,45,23,56,25,39,29,31,55,47,67,28,49,45,26,25,32,26,32,30,31,31,34,34,59,34,36,30,44,54,26,58,42,37,35,91,56,43,32,49,61,33,43,40,42,16,41,37,47,30,45,39,30,29,37,34,26,38,31,45,28,33,33,46,30,23,27,27,27,37,38,25,38,38,33,29,47,45,20,42,29,25,41,38,55,39,35,31,66,52,34,29,31,52,45,41,46,36,41,32,41,41,45,37,31,29,27,38,41,29,33,26,30,47,34,37,50,30,51,28,32,20,21,41,34,46,30,33,34,46,49,15,55,23,30,53,53,41,27,29,38,48,38,57,31,34,41,39,31,29,27,47,37,59,44,31,47,29,32,43,61,49,73,36,35,63,30,25,44,28,26,40,37,52,31,48,33,45,27,51,105,31,27,30,33,29,40,62,27,95,37,44,46,52,42,30,27,33,62,35,33,33,33,29,31,57,39,40,46,19,39,35,45,46,58,37,43,44,29,22,49,53,55,36,38,34,30,52,31,23,33,33,38,36,28,49,25,26,44,37,25,64,48,33,31,68,33,70,31,41,51,27,39,22,40,26,65,55,39,50,46,47,28,62,28,36,49,42,28,30,28,44,31,41,62,36,34,30,29,62,32,35,51,33,31,52,36,59,41,40,27,51,30,49,18,37,33,28,50,32,30,32,30,29,36,23,26,43,51,44,43,37,31,28,24,27,33,35,36,33,16,40,28,28,30,30,22,31,33,34,29,39,47,58,24,59,29,75,31,38,51,32,76,38,36,34,31,47,33,29,8,10,29,37,47,34,33,23,47,42,24,44,53,65,23,59,27,5 ...

# %%
## Drop rows that has No of Skills more thar 40 or less than 4
drop_skills_idx = Total_Skills_Count[(Total_Skills_Count > 40) | (Total_Skills_Count < 4)].index

# %%
## Drop from both data and original data 
data.drop(drop_skills_idx, axis=0, inplace=True)
original_data.drop(drop_skills_idx, axis=0, inplace=True)

# reset index of both data and original data
data.reset_index(drop=True, inplace=True)
original_data.reset_index(drop=True, inplace=True)

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Drop rows that has general jobs or not important jobs<span>

# %%
excluded_jobs = [
    'Other (please specify):',
    'Student',
    'Designer',
    'Educator',
    'Marketing or sales professional',
    'Engineering manager',
    'Senior Executive (C-Suite, VP, etc.)',
    'Product manager',
    'Project manager',
    'Developer Advocate',
    'Developer Experience',
    'Scientist',
    'Engineer, site reliability',
    'Academic researcher',
    'Research & Development role']

# %%
drop_DevType_idx = data[data['DevType'].isin(excluded_jobs)].index

# %%
## Drop from both data and original data
data.drop(drop_DevType_idx, axis=0, inplace=True)
original_data.drop(drop_DevType_idx, axis=0, inplace=True)

## Reset index of both data and original data
data.reset_index(drop=True, inplace=True)
original_data.reset_index(drop=True, inplace=True)

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Merge Close Jobs<span>

# %%
## Merge Embedded System Developer With Hardware Developer
close_job1_idx = data[data['DevType'].isin(['Developer, embedded applications or devices', 'Hardware Engineer'])].index

# %%
data['DevType'].loc[close_job1_idx] = "Developer, Hardware/Embedded Systems"
original_data['DevType'].loc[close_job1_idx] = "Developer, Hardware/Embedded Systems"

# %%
## Merge System Adminstration with Database Adminstration
close_job2_idx = data[data['DevType'].isin(['Database administrator','System administrator'])].index

# %%
data['DevType'].loc[close_job2_idx] = "Database/System Admininstrator"
original_data['DevType'].loc[close_job2_idx] = "Database/System Admininstrator"

# %%
## Merge Front-End , Back-End and Full-Stack as Web Developer
close_job3_idx = data[data['DevType'].isin(['Developer, back-end','Developer, front-end', 'Developer, full-stack'])].index

# %%
data['DevType'].loc[close_job3_idx] = "Web Developer"
original_data['DevType'].loc[close_job3_idx] = "Web Developer"

# %%
original_data['DevType'].loc[close_job1_idx]
# Out:
# 40       Developer, Hardware/Embedded Systems
# 519      Developer, Hardware/Embedded Systems
# 655      Developer, Hardware/Embedded Systems
# 732      Developer, Hardware/Embedded Systems
# 1008     Developer, Hardware/Embedded Systems
#                          ...
# 38036    Developer, Hardware/Embedded Systems
# 38076    Developer, Hardware/Embedded Systems
# 38132    Developer, Hardware/Embedded Systems
# 38228    Developer, Hardware/Embedded Systems
# 38316    Developer, Hardware/Embedded Systems
# Name: DevType, Length: 263, dtype: object

# %%
## Check Final Shape
data.shape
# Out:
# (38545, 8)

# %%
data
# Out:
#                                   LanguageHaveWorkedWith  \
# 0                          [Bash/Shell (all shells), Go]
# 1      [Bash/Shell (all shells), HTML/CSS, JavaScript...
# 2      [Bash/Shell (all shells), HTML/CSS, JavaScript...
# 3                                 [C, C++, Python, Rust]
# 4                               [Java, Perl, TypeScript]
# ...                                                  ...
# 38540  [Bash/Shell (all shells), HTML/CSS, JavaScript...
# 38541                 [C#, HTML/CSS, JavaScript, R, SQL]
# 38542                                     [Java, Kotlin]
# 38543                           [JavaScript, TypeScript]
# 38544                          [Dart, Java, Python, SQL]
#
#                                DatabaseHaveWorkedWith  \
# 0                                                  []
# 1                                 [PostgreSQL, Redis]
# 2      [BigQuery, Cloud Firestore, PostgreSQL, Redis]
# 3                                             [Redis]
# 4                                             [MySQL]
# ...                                               ...
# 38540                    [Oracle, PostgreSQL, SQLite]
# 38541                   [Microsoft SQL Server, MySQL]
# 38542                    [H2, MongoDB, MySQL, SQLite]
# 38543                                      [Dynamodb]
# 38544                                    [PostgreSQL]
#
#                                   PlatformHaveWorkedWith  \
# 0      [Amazon Web Services (AWS), Google Cloud, Open...
# 1                                   [Cloudflare, Heroku]
# 2      [Amazon Web Services (AWS), Cloudflare, Google...
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 38540                                           [VMware]
# 38541                                                 []
# 38542                                           [VMware]
# 38543                        [Amazon Web Services (AWS)]
# 38544                                                 []
#
#                                   WebframeHaveWorkedWith  \
# 0                                                     []
# 1      [Node.js, React, Ruby on Rails, Vue.js, WordPr...
# 2                    [Angular, Express, NestJS, Node.js]
# 3                                                     []
# 4                              [Fastify, Node.js, React]
# ...                                                  ...
# 38540                         [Express, jQuery, Node.js]
# 38541                          [ASP.NET CORE, WordPress]
# 38542                                      [Spring Boot]
# 38543                    [Express, Node.js, Spring Boot]
# 38544                                      [Spring Boot]
#
#                                   MiscTechHaveWorkedWith  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                     [Spring Framework]
# ...                                                  ...
# 38540                                                 []
# 38541                                          [Cordova]
# 38542                 [Opencv, OpenGL, Spring Framework]
# 38543                                     [Apache Kafka]
# 38544  [Flutter, Opencv, RabbitMQ, Spring Framework, ...
#
#                                  ToolsTechHaveWorkedWith  \
# 0                 [Cargo, Docker, Kubernetes, Make, Nix]
# 1                   [Homebrew, npm, Vite, Webpack, Yarn]
# 2      [Docker, Homebrew, Kubernetes, npm, pnpm, Terr...
# 3                  [Cargo, CMake, Docker, GNU GCC, Make]
# 4                                     [Kubernetes, Yarn]
# ...                                                  ...
# 38540            [APT, GNU GCC, Make, npm, Pip, Webpack]
# 38541                                              [npm]
# 38542               [Docker, Gradle, Maven (build tool)]
# 38543                           [Docker, Homebrew, Yarn]
# 38544                          [Maven (build tool), Pip]
#
#                             NEWCollabToolsHaveWorkedWith  \
# 0                                         [Emacs, Helix]
# 1      [IntelliJ IDEA, Vim, Visual Studio Code, WebSt...
# 2                                        [Helix, Neovim]
# 3               [Code::Blocks, Sublime Text, Vim, Xcode]
# 4                                   [Visual Studio Code]
# ...                                                  ...
# 38540                                              [Vim]
# 38541       [RStudio, Visual Studio, Visual Studio Code]
# 38542  [Android Studio, Atom, Eclipse, IntelliJ IDEA,...
# 38543          [IntelliJ IDEA, Nano, Visual Studio Code]
# 38544           [Android Studio, IntelliJ IDEA, PyCharm]
#
#                      DevType
# 0              Web Developer
# 1              Web Developer
# 2              Web Developer
# 3      Developer, QA or test
# 4              Web Developer
# ...                      ...
# 38540          Web Developer
# 38541          Web Developer
# 38542      Developer, mobile
# 38543          Web Developer
# 38544          Web Developer
#
# [38545 rows x 8 columns]

# %%
original_data.shape
# Out:
# (38545, 8)

# %%
## Dump Final Features 
data.to_pickle('Data/Cleaned_Features.pkl')
original_data.to_pickle('Data/Cleaned_original_data.pkl')

# %%
original_data
# Out:
#                      DevType  \
# 0              Web Developer
# 1              Web Developer
# 2              Web Developer
# 3      Developer, QA or test
# 4              Web Developer
# ...                      ...
# 38540          Web Developer
# 38541          Web Developer
# 38542      Developer, mobile
# 38543          Web Developer
# 38544          Web Developer
#
#                                   LanguageHaveWorkedWith  \
# 0                             Bash/Shell (all shells);Go
# 1      Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 2      Bash/Shell (all shells);HTML/CSS;JavaScript;Ru...
# 3                                      C;C++;Python;Rust
# 4                                   Java;Perl;TypeScript
# ...                                                  ...
# 38540  Bash/Shell (all shells);HTML/CSS;JavaScript;Pe...
# 38541                       C#;HTML/CSS;JavaScript;R;SQL
# 38542                                        Java;Kotlin
# 38543                              JavaScript;TypeScript
# 38544                               Dart;Java;Python;SQL
#
#                           DatabaseHaveWorkedWith  \
# 0                                            NaN
# 1                               PostgreSQL;Redis
# 2      BigQuery;Cloud Firestore;PostgreSQL;Redis
# 3                                          Redis
# 4                                          MySQL
# ...                                          ...
# 38540                   Oracle;PostgreSQL;SQLite
# 38541                 Microsoft SQL Server;MySQL
# 38542                    H2;MongoDB;MySQL;SQLite
# 38543                                   Dynamodb
# 38544                                 PostgreSQL
#
#                                   PlatformHaveWorkedWith  \
# 0      Amazon Web Services (AWS);Google Cloud;OpenSta...
# 1                                      Cloudflare;Heroku
# 2      Amazon Web Services (AWS);Cloudflare;Google Cloud
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 38540                                             VMware
# 38541                                                NaN
# 38542                                             VMware
# 38543                          Amazon Web Services (AWS)
# 38544                                                NaN
#
#                              WebframeHaveWorkedWith  \
# 0                                               NaN
# 1      Node.js;React;Ruby on Rails;Vue.js;WordPress
# 2                    Angular;Express;NestJS;Node.js
# 3                                               NaN
# 4                             Fastify;Node.js;React
# ...                                             ...
# 38540                        Express;jQuery;Node.js
# 38541                        ASP.NET CORE;WordPress
# 38542                                   Spring Boot
# 38543                   Express;Node.js;Spring Boot
# 38544                                   Spring Boot
#
#                                   MiscTechHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                       Spring Framework
# ...                                                  ...
# 38540                                                NaN
# 38541                                            Cordova
# 38542                     Opencv;OpenGL;Spring Framework
# 38543                                       Apache Kafka
# 38544  Flutter;Opencv;RabbitMQ;Spring Framework;Torch...
#
#                              ToolsTechHaveWorkedWith  \
# 0                   Cargo;Docker;Kubernetes;Make;Nix
# 1                     Homebrew;npm;Vite;Webpack;Yarn
# 2      Docker;Homebrew;Kubernetes;npm;pnpm;Terraform
# 3                    Cargo;CMake;Docker;GNU GCC;Make
# 4                                    Kubernetes;Yarn
# ...                                              ...
# 38540               APT;GNU GCC;Make;npm;Pip;Webpack
# 38541                                            npm
# 38542               Docker;Gradle;Maven (build tool)
# 38543                           Docker;Homebrew;Yarn
# 38544                         Maven (build tool);Pip
#
#                             NEWCollabToolsHaveWorkedWith
# 0                                            Emacs;Helix
# 1          IntelliJ IDEA;Vim;Visual Studio Code;WebStorm
# 2                                           Helix;Neovim
# 3                    Code::Blocks;Sublime Text;Vim;Xcode
# 4                                     Visual Studio Code
# ...                                                  ...
# 38540                                                Vim
# 38541           RStudio;Visual Studio;Visual Studio Code
# 38542  Android Studio;Atom;Eclipse;IntelliJ IDEA;Netb...
# 38543              IntelliJ IDEA;Nano;Visual Studio Code
# 38544               Android Studio;IntelliJ IDEA;PyCharm
#
# [38545 rows x 8 columns]
